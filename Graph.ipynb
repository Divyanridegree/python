# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanridegree/python/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import random
x=[]

# %%
y=[]

# %%
[x.append(random.randint(0,25)) for _ in range(10)]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
[y.append(random.randint(0,25)) for _ in range(10)]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
print(x)
# Out:
# [5, 19, 5, 23, 23, 21, 24, 7, 21, 7]

# %%
print(y)
# Out:
# [7, 22, 22, 18, 2, 9, 17, 25, 10, 16]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(x,y)
